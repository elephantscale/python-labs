# %% [markdown]
# 2-plot-cars Lab
# ==================
#
# ### Overview
# - Learn matplotlib library
#
# ### Depends On
# None
#
# ### Run time
# 15-20 mins

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Cars Dataset
#
# The "cars" dataset has speed and stopping distance of different cars. Each line is a different observation.

# %%
cars = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/cars/cars.csv')
cars
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %% [markdown]
# **=> Plot a matplotlib graph to demonstrate the relationship between speed and stopping distance.**
#
# **=> Add title, and labels for X and Y axis.**

# %% [markdown]
# ## Cars93 dataset
#
# **=> Import Cars93 dataset.**

# %%
Cars93 = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/cars/cars93.csv')
Cars93
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0         25           31                None  ...          5    177
# 1         18           25  Driver & Passenger  ...          5    195
# 2         20           26         Driver only  ...          5    180
# 3         19           26  Driver & Passenger  ...          6    193
# 4         22           30         Driver only  ...          4    186
# ..       ...          ...                 ...  ...        ...    ...
# 88        17           21                None  ...          7    187
# 89        21           30                None  ...          5    180
# 90        18           25                None  ...          4    159
# 91        21           28         Driver only  ...          5    190
# 92        20           28  Driver & Passenger  ...          5    184
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 0         102     68           37            26.5         11.0    2705
# 1         115     71           38            30.0         15.0    3560
# 2         102     67           37            28.0         14.0    3375
# 3         106     70           37            31.0         17.0    3405
# 4         109     69           39            27.0         13.0    3640
# ..        ...    ...          ...             ...          ...     ...
# 88        115     72           38            34.0          NaN    3960
# 89        103     67           35            31.5         14.0    2985
# 90         97     66           36            26.0         15.0    2810
# 91        104     67           37            29.5         14.0    2985
# 92        105     69           38            30.0         15.0    3245
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 2   non-USA             Audi 90
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# ..      ...                 ...
# 88  non-USA  Volkswagen Eurovan
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [93 rows x 28 columns]

# %% [markdown]
# **=> Calculate average MPG.city for each car type.**

# %%
Cars93['MPG.avg'] = (Cars93['MPG.city'] + Cars93['MPG.highway']) / 2

## Calculate avg MPG for each type
m = Cars93.groupby('Type').agg({'MPG.avg': 'mean'}) 
m
# Out:
#            MPG.avg
# Type
# Compact  26.281250
# Large    22.545455
# Midsize  23.136364
# Small    32.666667
# Sporty   25.285714
# Van      19.444444

# %% [markdown]
# **=> Do a matplotlib barplot on car Type vs average mileage.**

# %%
# TODO: Do a bar plot

m.plot.bar(color=[['r','g']])

# %% [markdown]
# **=> Add colors to the graph!**
#
# Hint: set the color parameter on the pyplot bar. It is a list of the colors you want. ['yellow', 'maroon']

# %%
# TODO: Add Colors

# %% [markdown]
# ### Boxplot
# **=> BoxPlot  Car type vs MPG.**

# %%
# TODO: Perform Boxplot

plt.boxplot(Cars93['MPG.avg'], by=Cars93['Type'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5bbcb59565bf> in <module>
#       1 # TODO: Perform Boxplot
#       2
# ----> 3 plt.boxplot(Cars93['MPG.avg'], by=Cars93['Type'])
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %% [markdown]
# ### Histograms
#
# **=> Do a histogram on car prices.**

# %%
# TODO: Perform Histogram

# %% [markdown]
# **=> Do a discrete histogram for car types.**
# Note: `hist`  works well with continuous values.
# Hint: use pandas df.value_counts function to calculate frequencies, then plot.

# %%
# TODO: Hisogram of car types

# %% [markdown]
# ### Hmmm... Pie!
# **=> Do a pie-chart on  US vs non-US models**

# %%
# Do a pie chart.

# %% [markdown]
# ### Save Graphs
# And finally export a graph into a file (pdf or png)
#
# you can use plt.savefig()

# %%
# Save graph.

# %% [markdown]
# ### Scatter Plot Matrix
#
# How do we plot in more than 2 or 3 dimensions?
#
# Use a scatter plot matrix?

# %%
trees = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/rainfall/trees.csv')
trees

# %%
import seaborn as sns
sns.set(style="ticks")

sns.pairplot(trees)

# %% [markdown]
# **=> Do you spot any relation between Girth, Height and Volume?**
#
# **=> Plot those two attributes in a separate graph.**
